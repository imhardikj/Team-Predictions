# %% [markdown]
# # Cleaning the data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('IPL DATASET/IPL2018.csv')

# %%
df.replace('-',np.nan,inplace=True)

# %%
df['Strike Rate'] = pd.to_numeric(df['Strike Rate'],)

# %%
#df.shape
df
# Out:
#      Sl.No       Player's Name Team From  Run  Ball  Strike Rate  4's  6's  \
# 0        1         Aaron Finch  KXI  AUS  134   100        134.0    6    8
# 1        2      AB de Villiers  RCB   SA  480   275        174.5   39   30
# 2        3     Abhishek Sharma   DD  IND   63    33        190.9    3    5
# 3        4         Aditya Tare   MI  IND    0     0          NaN    0    0
# 4        5      Ajinkya Rahane   RR  IND  370   313        118.2   39    5
# 5        6     Akila Dananjaya   MI   SL    4     5         80.0    0    0
# 6        7       Akshdeep Nath  KXI  IND    9    13         69.2    1    0
# 7        8          Alex Hales  SRH  ENG  148   118        125.4   13    6
# 8        9       Ambati Rayudu  CSK  IND  602   402        149.8   53   34
# 9       10         Amit Mishra   DD  IND    1     2         50.0    0    0
# 10      11       Andre Russell  KKR   WI  316   171        184.8   17   31
# ...

# %%
df.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83 entries, 5 to 195
# Data columns (total 19 columns):
# Sl.No                 83 non-null int64
# Player's Name         83 non-null object
# Team                  83 non-null object
# From                  83 non-null object
# Run                   83 non-null int64
# Ball                  83 non-null int64
# Strike Rate           83 non-null float64
# 4's                   83 non-null int64
# 6's                   83 non-null int64
# Highest Run Scored    83 non-null int64
# Balls  Bowled         83 non-null int64
# Runs Scored           83 non-null int64
# Economy               83 non-null object
# Wickets               83 non-null int64
# Ct_St                 83 non-null int64
# Run Outs              83 non-null float64
# Matches Played        83 non-null int64
# Age                   83 non-null float64
# Type                  83 non-null object
# dtypes: float64(3), int64(11), object(5)
# memory usage: 13.0+ KB

# %%
#x = df.iloc[10]['Strike Rate']
#x+10

# %%
import seaborn as sns
sns.heatmap(df.isnull(),cbar=False,cmap='rainbow')

# %%
import cufflinks as cf
import matplotlib.pyplot as plt

# %%
sns.set_style('dark')
df1 = df['Strike Rate'].dropna().hist(bins=50)
plt.title('Strike rate Dist plot')
plt.xlabel('Strike Rate')
plt.ylabel('No. of players')
# Out:
# Text(0,0.5,'No. of players')

# %%
df.head()
# Out:
#    Sl.No    Player's Name Team From  Run  Ball  Strike Rate  4's  6's  \
# 0      1      Aaron Finch  KXI  AUS  134   100        134.0    6    8
# 1      2   AB de Villiers  RCB   SA  480   275        174.5   39   30
# 2      3  Abhishek Sharma   DD  IND   63    33        190.9    3    5
# 3      4      Aditya Tare   MI  IND    0     0          NaN    0    0
# 4      5   Ajinkya Rahane   RR  IND  370   313        118.2   39    5
#
#    Highest Run Scored  Balls  Bowled  Runs Scored Economy  Wickets  Ct_St  \
# 0                  46              0            0     NaN        0      4
# 1                  90              0            0     NaN        0      6
# 2                  46              0            0     NaN        0      1
# 3                   0              0            0     NaN        0      1
# 4                  65              0            0     NaN        0      4
#
#    Run Outs  Matches Played   Age Type
# 0       0.0              10  31.0  BAT
# ...
