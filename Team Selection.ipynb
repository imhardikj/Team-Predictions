# %% [markdown]
# # ALL STARS IPL-Team

# %% [markdown]
# ** Selection of team on basis of Past IPL perfomances. **

# %% [markdown]
# ## Batsmen

# %% [markdown]
# ### Rohit Sharma
# ### Shane Watson
# ### Virat Kohli
# ### AB de Villiers
# ### Suresh Raina

# %% [markdown]
# ## Wicket Keeper

# %% [markdown]
# ### MS Dhoni

# %% [markdown]
# ## All Rounders

# %% [markdown]
# ### Andre Russel
# ### Hardik Pandya

# %% [markdown]
# ## Bowlers

# %% [markdown]
# ### Sunil Narine
# ### Bhuvneshwar Kumar
# ### Jasprit Bumrah

# %%
import pandas as pd
df = pd.read_csv('All Stars.csv')
df
# Out:
#     Sl. No.             Player  Age Team From  Matches Played  Runs  Average  \
# 0         1       Rohit Sharma   31   MI  IND             173  4493    31.86
# 1         2       Shane Watson   37  CSK  AUS             117  3177    32.41
# 2         3        Virat Kohli   30  RCB  IND             163  4948    38.35
# 3         4     AB de Villiers   34  RCB   SA             141  3953    39.53
# 4         5       Suresh Raina   32  CSK  IND             176  4985    34.37
# 5         6           MS Dhoni   37  CSK  IND             175  4016    40.16
# 6         7       Andre Russel   30  KKR   WI              50   890    26.96
# 7         8      Hardik Pandya   25   MI  IND              50   666    23.78
# 8         9       Sunil Narine   30  KKR   WI              98   628    17.44
# 9        10  Bhuvneshwar Kumar   28  SRH  IND             102   171     8.14
# 10       11     Jasprit Bumrah   25   MI  IND              61    35    11.66
#
# ...
