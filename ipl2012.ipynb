# %%
import numpy as np
import  pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df12 = pd.read_excel('IPL DATASET/IPL2012.xlsx')

# %%
df12.head()
# Out:
#    Sl No    Player's Name Team From  Run  Ball Strike Rate  Four  Six  \
# 0      1       A Chandila   RR  IND    0     1           0     0    0
# 1      2    Aakash Chopra   RR  IND    0     0           -     0    0
# 2      3      Aaron Finch   DD  AUS   55    51     107.843     8    0
# 3      4  Aavishkar Salvi   DD  IND    0     0           -     0    0
# 4      5   AB de Villiers  RCB   SA  317   198     160.101    26   15
#
#    Balls Bowled  Runs Concede  Economy  Wickets  Ct_St  Matches Played  Age
# 0            84            86  6.14286        5      3               4   28
# 1             0             0        -        0      0               0   34
# 2             0             0        -        0      0               2   25
# 3             0             0        -        0      0               0   30
# 4             0             0        -        0      9              15   28

# %%
df12.replace('-',np.nan,inplace=True)

# %%
df12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 16 columns):
# Sl No             279 non-null int64
# Player's Name     279 non-null object
# Team              279 non-null object
# From              279 non-null object
# Run               279 non-null int64
# Ball              279 non-null int64
# Strike Rate       168 non-null float64
# Four              279 non-null int64
# Six               279 non-null int64
# Balls Bowled      279 non-null int64
# Runs Concede      279 non-null int64
# Economy           127 non-null float64
# Wickets           279 non-null int64
# Ct_St             279 non-null int64
# Matches Played    279 non-null int64
# Age               279 non-null int64
# dtypes: float64(2), int64(11), object(3)
# memory usage: 31.6+ KB

# %%
#df12.head()

# %%
df12.describe()
# Out:
#             Sl No         Run        Ball  Strike Rate        Four  \
# count  279.000000  279.000000  279.000000   168.000000  279.000000
# mean   140.000000   73.881720   60.240143   110.792966    6.630824
# std     80.684571  129.937992  101.091079    51.478749   12.658346
# min      1.000000    0.000000    0.000000     0.000000    0.000000
# 25%     70.500000    0.000000    0.000000    91.794218    0.000000
# 50%    140.000000    6.000000    7.000000   111.696765    0.000000
# 75%    209.500000   88.500000   74.000000   130.937268    7.500000
# max    279.000000  733.000000  456.000000   400.000000   73.000000
#
#               Six  Balls Bowled  Runs Concede     Economy     Wickets  \
# count  279.000000    279.000000    279.000000  127.000000  279.000000
# mean     2.512545     59.774194     75.835125    8.637824    2.677419
# std      5.581865     99.318954    122.524266    2.524178    4.884629
# min      0.000000      0.000000      0.000000    5.202417    0.000000
# ...
