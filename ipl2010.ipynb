# %%
import numpy as np
import  pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df10 = pd.read_excel('IPL DATASET/IPL2010.xls')

# %%
df10.head()
# Out:
#    Sl no       Player Name Team From   Runs  Balls  Four  Six  \
# 0      1           A Ahmed   MI  NaN    4.0    7.0   0.0  0.0
# 1      2          A Uniyal   RR  IND    4.0    7.0   0.0  0.0
# 2      3   Aavishkar Salvi   DD  IND    0.0    0.0   0.0  0.0
# 3      4    AB de Villiers   DD   SA  111.0  119.0   7.0  0.0
# 4      5  Abhimanyu Mithun  RCB  IND    5.0    4.0   1.0  0.0
#
#    Highest Run Scored  Strike Rate  Balls Bowled  Runs Conceded  Economy  \
# 0                   4    57.142857          12.0           26.0     13.0
# 1                   4    57.142857          36.0           66.0     11.0
# 2                   0          NaN           0.0            0.0      NaN
# 3                  45    93.277311           0.0            0.0      NaN
# 4                   5   125.000000          18.0           39.0     13.0
#
#    Wickets  ct_st  Run Outs  Matches Played   Age
# 0      0.0      0       0.0               1   NaN
# 1      2.0      0       1.0               3  28.0
# ...

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 18 columns):
# Sl no                 204 non-null int64
# Player Name           204 non-null object
# Team                  204 non-null object
# From                  199 non-null object
# Runs                  203 non-null float64
# Balls                 203 non-null float64
# Four                  203 non-null float64
# Six                   203 non-null float64
# Highest Run Scored    204 non-null int64
# Strike Rate           162 non-null float64
# Balls Bowled          203 non-null float64
# Runs Conceded         203 non-null float64
# Economy               121 non-null float64
# Wickets               203 non-null float64
# ct_st                 204 non-null int64
# Run Outs              204 non-null float64
# Matches Played        204 non-null int64
# Age                   194 non-null float64
# dtypes: float64(11), int64(4), object(3)
# memory usage: 26.3+ KB

# %%
df10.describe()
# Out:
#             Sl no        Runs       Balls        Four         Six  \
# count  204.000000  203.000000  203.000000  203.000000  203.000000
# mean   102.500000   87.113300   68.610837    8.389163    2.896552
# std     59.033889  133.820265   99.908281   14.288099    5.406646
# min      1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     51.750000    1.000000    2.000000    0.000000    0.000000
# 50%    102.500000   19.000000   19.000000    1.000000    0.000000
# 75%    153.250000  113.000000  108.000000   10.500000    3.000000
# max    204.000000  618.000000  494.000000   86.000000   28.000000
#
#        Highest Run Scored  Strike Rate  Balls Bowled  Runs Conceded  \
# count          204.000000   162.000000    203.000000     203.000000
# mean            24.578431   106.141395     68.231527      90.325123
# std             29.072166    55.059286     95.815678     121.166658
# min              0.000000     0.000000      0.000000       0.000000
# ...
